# %%
# !pip install seaborn --upgrade
# Out:
# ...
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)

# %%
# !pip install mlxtend
# Out:
# ...
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\ajarir\anaconda3\lib\site-packages)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# for Box-Cox Transformation
from scipy import stats

# for min_max scaling
from mlxtend.preprocessing import minmax_scaling

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline


import matplotlib.pyplot as plt

# set seed for reproducibility
np.random.seed(0)

# %% [markdown]
# # norm

# %%
# generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size=100)

# mi-max scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns=[0])

# plot both together to compare
fig, ax = plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(scaled_data, ax=ax[1], kde=True, legend=False)
ax[1].set_title("Scaled data")
plt.show()

# %%
sns.histplot(scaled_data, ax=ax[1], kde=True, legend=False)
ax[1].set_title("Scaled data")
plt.show()

# %%
#Generate random data
data = np.random.exponential(size=1000)

#Scale the data between 0 and 1
scaled_data = minmax_scaling(data, columns=[0])

#Plot original data as a histogram
plt.subplot(1, 2, 1)
sns.distplot(data, hist=True, kde=False, color='b')
plt.title('Original Data')

#Plot scaled data as a histogram
plt.subplot(1, 2, 2)
sns.distplot(scaled_data, hist=True, kde=False, color='r')

plt.title('Scaled Data')

plt.show()

# %%
# generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size=100)

# min-max scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns=[0])

# plot both together to compare
# plot original data as a kernel density estimate
plt.subplot(1, 2, 1)
sns.kdeplot(data, color='r', linewidth=3, shade=True)
plt.title('Original Data')
# Out:
# Text(0.5, 1.0, 'Original Data')

# %%
# generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size=100)

# min-max scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns=[0])

# plot both together to compare
fig, ax = plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(scaled_data, ax=ax[1], kde=True, legend=False)
ax[1].set_title("Scaled data")
plt.show()


plt.subplot(1, 2, 1)
sns.kdeplot(data, color='r', linewidth=3, shade=True)
plt.title('Original Data')

# %%
# generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size=100)

# min-max scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns=[0])

# plot original data
fig, ax = plt.subplots(figsize=(7, 3))

# plot the histogram graph 
sns.histplot(original_data, ax=ax, kde=True, legend=False)

ax.set_title("Original Data")
plt.show()

# %%
# plot scaled data
fig, ax = plt.subplots(figsize=(7, 3))
sns.histplot(scaled_data, ax=ax, kde=True, legend=False)
ax.set_title("Scaled data")
plt.show()
